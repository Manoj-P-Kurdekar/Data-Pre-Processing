# %%
# Python Libraries (Packages)
# importing required modules
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pylab

# %%
#reading the data into python
df = pd.read_csv(r"C:\Users\manoj\OneDrive\Desktop\360DigiTMG\Data Science\Assignment Question\Data Pre Processing\DataSets-Data Pre Processing\calories_consumed.csv")
df
# Out:
#     Weight gained (grams)  Calories Consumed
# 0                     108               1500
# 1                     200               2300
# 2                     900               3400
# 3                     200               2200
# 4                     300               2500
# 5                     110               1600
# 6                     128               1400
# 7                      62               1900
# 8                     600               2800
# 9                    1100               3900
# 10                    100               1670
# 11                    150               1900
# 12                    350               2700
# 13                    700               3000

# %%
df.dtypes   #to chck the variable types of columns
# Out:
# Weight gained (grams)    int64
# Calories Consumed        int64
# dtype: object

# %%
df.isnull().sum() #finding weather any null values is in presence
# Out:
# Weight gained (grams)    0
# Calories Consumed        0
# dtype: int64

# %%
df.shape     # shape of the column
# Out:
# (14, 2)

# %%
print('\n','mean','\n')
print(df.mean())
print('\n','median','\n')
print(df.median())
print('\n','mode','\n')
print(df.mode())
print('\n','variance','\n')
print(df.var())
print('\n','standard deviation','\n')
print(df.std())
print('\n','skewness','\n')
print(df.skew())
print('\n','kurtosis','\n')
print(df.kurt())
# Out:
#  mean
#
# Weight gained (grams)     357.714286
# Calories Consumed        2340.714286
# dtype: float64
#
#  median
#
# Weight gained (grams)     200.0
# Calories Consumed        2250.0
# dtype: float64
#
#  mode
#
#    Weight gained (grams)  Calories Consumed
# 0                    200               1900
#
#  variance
#
# Weight gained (grams)    111350.681319
# Calories Consumed        565668.681319
# dtype: float64
#
#  standard deviation
#
# Weight gained (grams)    333.692495
# Calories Consumed        752.109488
# dtype: float64
#
#  skewness
#
# Weight gained (grams)    1.255737
# Calories Consumed        0.654930
# dtype: float64
#
#  kurtosis
#
# Weight gained (grams)    0.431272
# Calories Consumed       -0.290481
# dtype: float64

# %%
prob = stats.probplot(df['Weight gained (grams)'], dist = stats.norm, plot = pylab)   # Original data

# %%
prob = stats.probplot(df['Calories Consumed'], dist = stats.norm, plot = pylab)    # Original data

# %%
from feature_engine import transformation

# %%
# Set up the variable transformer
tf = transformation.YeoJohnsonTransformer(variables=['Weight gained (grams)','Calories Consumed'])

# %%
res = tf.fit_transform(df)

# %%
prob = stats.probplot(res['Weight gained (grams)'], dist = stats.norm, plot = pylab)      ### Transformed data

# %%
prob = stats.probplot(res['Calories Consumed'], dist = stats.norm, plot = pylab)  ### Transformed data
