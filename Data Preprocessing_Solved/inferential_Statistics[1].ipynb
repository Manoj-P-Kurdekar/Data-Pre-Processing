# %%
import pandas as pd #import required libraries

# %%
#read file into python 
df=pd.read_excel(r"C:\Users\manoj\OneDrive\Desktop\360DigiTMG\Data Science\Assignment Question\Data Pre Processing\DataSets-Data Pre Processing\Assignment_module02 (1).xlsx")
df
# Out:
#     Points  Score  Weigh
# 0     3.90  2.620  16.46
# 1     3.90  2.875  17.02
# 2     3.85  2.320  18.61
# 3     3.08  3.215  19.44
# 4     3.15  3.440  17.02
# 5     2.76  3.460  20.22
# 6     3.21  3.570  15.84
# 7     3.69  3.190  20.00
# 8     3.92  3.150  22.90
# 9     3.92  3.440  18.30
# 10    3.92  3.440  18.90
# 11    3.07  4.070  17.40
# 12    3.07  3.730  17.60
# 13    3.07  3.780  18.00
# 14    2.93  5.250  17.98
# 15    3.00  5.242  17.82
# 16    3.23  5.345  17.42
# 17    4.08  2.200  19.47
# 18    4.93  1.615  18.52
# 19    4.22  1.835  19.90
# 20    3.70  2.465  20.01
# 21    2.76  3.520  16.87
# 22    3.15  3.435  17.30
# 23    3.73  3.840  15.41
# 24    3.08  3.845  17.05
# 25    4.08  1.935  18.90
# 26    4.43  2.140  16.70
# 27    3.77  1.513  16.90
# 28    4.22  3.170  14.50
# 29    3.62  2.770  15.50
# 30    3.54  3.570  14.60
# 31    4.11  2.780  18.60

# %%
print('Mean','\n')
print(df.mean())
print('\n',"Median"'\n')
print(df.median())
print('\n','Mode','\n')
print(df.mode())
print('\n','Standatd deviation','\n')
print(df.var())
print('\n','variance','\n')
print(df.std())
# Out:
# Mean
#
# Points     3.596563
# Score      3.211562
# Weigh     17.848750
# dtype: float64
#
#  Median
#
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64
#
#  Mode
#
#    Points  Score  Weigh
# 0    3.07   3.44  17.02
# 1    3.92    NaN  18.90
#
#  Standatd deviation
#
# Points    0.285881
# Score     0.932503
# Weigh     3.193166
# dtype: float64
#
#  variance
#
# Points    0.534679
# Score     0.965662
# Weigh     1.786943
# dtype: float64

# %%
range = max(df.Weigh) - min(df.Points) # range
print('\n','range')
print(range)
# Out:
#  range
# 20.14
